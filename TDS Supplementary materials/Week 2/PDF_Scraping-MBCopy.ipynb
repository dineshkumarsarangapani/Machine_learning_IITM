# %% [markdown]
# Importing the required libraries

# %% [markdown]
# # **Tutorial To Scrape PDFs from a Given URL**
# This tutorial will help us to download all the PDFs in a given URL. In addition to downloading the PDF, this tutorial also helps us in reading a PDF and saving a table from the PDF to a conservative structured format like a CSV.

# %%
import os
import pandas as pd
import requests
import urllib.request
import pandas as pd
from urllib.parse import urljoin
from bs4 import BeautifulSoup

# %%
# Tabula scrapes tables from PDFs
# !pip install tabula-py
import tabula
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tabula

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# The url input for dowloading pdfs and setting up output folder path

# %%
df3 = tabula.read_pdf('/content/drive/Shareddrives/Tools for Data Science/India Election Data/west-bengal-2011.pdf',pages='all',multiple_tables=True)
# Out:
# WARNING:tabula.io:Got stderr: Nov 01, 2022 4:50:45 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Nov 01, 2022 4:50:45 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Nov 01, 2022 4:50:45 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 17 fonts
# Nov 01, 2022 4:50:45 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Nov 01, 2022 4:50:45 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats

# %%
import os
fnames = os.listdir('/content/drive/Shareddrives/Tools for Data Science/India Election Data/')
print(len(fnames))
# Out:
# 338

# %%
len(results)
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0a0a1472db4e> in <module>
# ----> 1 len(results)
#       2 results
#
# NameError: name 'results' is not defined

# %%
results

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
results1

# %%
df3[19].iloc[:,-1:].dropna()

# %%
os.chdir('/content/drive/Shareddrives/Tools for Data Science/India Election Data/')
results1 = {}
results2 = {}
i = 1
for filename in fnames:
  try:

    df = tabula.read_pdf(filename,pages='1-100',multiple_tables=True, silent=True)
    temp = df[19].iloc[:,-1:].dropna()
    temp.columns = ['votes']
    temp = temp[~temp['votes'].isin(['Total','Valid','Votes','votes','TOTAL','VALID','VOTES','total','valid'])]
    temp['votes'] = temp['votes'].astype(int)
    answer1 = len(temp[temp['votes']<100000])
    answer2 = temp['votes'].mean()
    print(i, filename, len(temp), answer1, answer2)
    i = i+1
    results1[filename] = answer1
    results2[filename] = answer2
  except:
    print('Skipping file')
    i = i+1
    continue
    
df1 = pd.DataFrame(results1.items(), columns=['filename', 'answer1'])
df2 = pd.DataFrame(results2.items(), columns=['filename', 'answer2'])
df = pd.merge(df1,df2,on=['filename'],how='inner')
df.to_csv('results.csv')

# %%
import os
os.chdir('/content/drive/Shareddrives/Tools for Data Science/India Election Data/')
df11 = pd.read_csv('results.csv')

# %%
df11 = df11.loc[:, ~df11.columns.str.contains('^Unnamed')]
df11.head()

# %%
df11['answer12'] = df11['answer1'].shift(-1).fillna(99)
df11['answer13'] = df11['answer12'].shift(-1).fillna(77)
df11['answer14'] = df11['answer13'].shift(-1).fillna(67)
df11['answer22'] = df11['answer2'].shift(-1).fillna(137546.65)
df11['answer23'] = df11['answer22'].shift(-1).fillna(148797.55)
df11['answer24'] = df11['answer23'].shift(-1).fillna(93714.67)

# %%
df11['answer2'] = df11['answer2'].round(2)

# %%
df11.head()

# %%
df11.to_csv('final_results.csv',index=False)

# %%
df.shape

# %%
df.shape

# %%
df = tabula.read_pdf('west-bengal-2011.pdf',pages='all',multiple_tables=True)

# %%
df2 = tabula.read_pdf('west-bengal-2006.pdf',pages='all',multiple_tables=True)

# %%
df[19]

# %%
df2[19]

# %%
 temp = df2[19].iloc[:,-1:].dropna()
 temp.columns = ['votes']
 temp = temp[~temp['votes'].isin(['Total','Valid','Votes'])]
 temp['votes'] = temp['votes'].astype(int)
 print(len(temp), len(temp[temp['votes']>10]))

# %%
# Save contents from url into folder_location
url = 'https://www.premierleague.com/publications'
folder_location = r'/content/drive/MyDrive/Colab Notebooks/premier_league'
if not os.path.exists(folder_location):
    os.mkdir(folder_location)

# %% [markdown]
# Actual Code

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")     

# Loop through all PDF links in the page
for link in soup.select("a[href$='.pdf']"):
    # Local lile name is the same as PDF file name in the URL (ignoring rest of the path)
    # https://premierleague-static-files.s3.amazonaws.com/premierleague/document/2016/07/02/e1648e96-4eeb-456e-8ce0-d937d2bc7649/2011-12-premier-league-season-review.pdf
    filename = os.path.join(folder_location, link['href'].split('/')[-1])
    with open(filename, 'wb') as f:
        f.write(requests.get(urljoin(url,link['href'])).content)

# %% [markdown]
# Reading a table from a PDF document and storing it in a csv file

# %%
  combined_pdf = folder_location + "/This-is-PL-Interactive-Combined.pdf"
tabula.read_pdf(combined_pdf,  pages='18')

# %%
from tabula import convert_into

convert_into(combined_pdf, folder_location +"/table_output.csv", output_format="csv",pages = 18,area=[[275,504,640,900]])
pd.read_csv(folder_location+"/table_output.csv")
